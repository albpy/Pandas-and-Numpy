# %% [markdown]
# # Python
# Python is a Cross Platform Programming language,Which means that it runs on on Multiple Platforms like Linux,Windows,MacOS.
# It is free and open-source.

# %% [markdown]
# ### Python Keywords
# Python keywords are reserved words
# We cannot use a keyword as a variable and function .Because they are used to define the syntax as well as the structure of the Python programming language.

# %%
from IPython.display import Image
Image("keyword.png",width=800, unconfined=True)

# %% [markdown]
# ### Python Identifiers

# %% [markdown]
# Python identifiers aims to provide a name to the entities like function,class,variables etc.and it mainly used for the differentiate one entity from another.

# %% [markdown]
# Rules for writing identifiers
#
#     1)Identifiers can be a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore _. Names like myClass, var_1 and print_this_to_screen, all are valid example.
#     2)An identifier cannot start with a digit. 1variable is invalid, but variable1 is a valid name.
#     3)Keywords cannot be used as identifiers.

# %% [markdown]
# ### Python Comments

# %% [markdown]
# This notebook will just go through the basic topics:
#
# * Data types
#     * Numbers
#     * Strings
#     * Printing
#     * Lists
#     * Dictionaries
#     * Booleans
#     * Tuples
#     * Sets
# * Comparison Operators
# * if, elif, else Statements
# * for Loops
# * while Loops
# * range()
# * list comprehension
# * functions
# * methods

# %%
## Data types

### Numbers

# %%
1 + 1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
4 % 2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ### Variable Assignment

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z
# Out:
# 5

# %%
from IPython.display import Image
Image("Python.jpg",width=800, unconfined=True)

# %% [markdown]
# ### Strings

# %% [markdown]
# Strings are arrays of bytes representing Unicode characters

# %%
'Welcome to ICFOSS'
# Out:
# 'Welcome to ICFOSS'

# %%
"Welcome to ICFOSS"
# Out:
# 'Welcome to ICFOSS'

# %%
"Let's start the online class "
# Out:
# "Let's start the online class "

# %% [markdown]
# ### multi-line strings

# %% [markdown]
# We can use either ''' or """ for multi-line strings

# %%
"""This is also a 
best example of
multi-line comments"""
# Out:
# 'This is also a \nbest example of\nmulti-line comments'

# %% [markdown]
# ### Printing

# %%
x = 'ICFOSS'

# %%
x
# Out:
# 'ICFOSS'

# %%
print(x)
# Out:
# ICFOSS

# %%
Year = 2020 
name = 'Deepu'

# %%
print('Present year is : {one}, and my name: {two}'.format(one=Year,two=name))
# Out:
# Present year is : 2020, and my name: Deepu

# %%
print('Present year is: {}, and my name is: {}'.format(Year,name))
# Out:
# Present year is: 2020, and my name is: Deepu

# %% [markdown]
# ### Lists

# %% [markdown]
# List is a collection which is ordered and changeable. Allows duplicate members.

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['ICFOSS',1,[1,2]]
# Out:
# ['ICFOSS', 1, [1, 2]]

# %%
my_list = ['manu','sanu','vinu']

# %%
my_list.append('rinu')

# %%
my_list
# Out:
# ['manu', 'sanu', 'vinu', 'rinu']

# %%
my_list[0]
# Out:
# 'manu'

# %%
my_list[1]
# Out:
# 'sanu'

# %%
my_list[1:]
# Out:
# ['sanu', 'vinu', 'rinu']

# %%
my_list[:1]
# Out:
# ['manu']

# %%
my_list[0] = 'anu'

# %%
my_list
# Out:
# ['anu', 'sanu', 'vinu', 'rinu']

# %%
nest = [1,2,3,[4,5,['ICFOSS']]]

# %%
nest[3]
# Out:
# [4, 5, ['ICFOSS']]

# %%
nest[3][2]
# Out:
# ['ICFOSS']

# %%
nest[3][2][0]
# Out:
# 'ICFOSS'

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# Dictionary is a collection which is unordered, changeable and indexed. No duplicate members.

# %%
d = {'key1':'item1','key2':'item2'}

# %%
d
# Out:
# {'key1': 'item1', 'key2': 'item2'}

# %%
d['key1']
# Out:
# 'item1'

# %%
employee = {1:"kailas",2:"sudhi",3:"jaison"}
employee.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
employee.values()
# Out:
# dict_values(['kailas', 'sudhi', 'jaison'])

# %% [markdown]
# ### Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# ### Tuples

# %% [markdown]
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-93bfe9be1549> in <module>()
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Sets

# %% [markdown]
# Set is a collection which is unordered and unindexed. No duplicate members.

# %%
{1,2,3}

# %%
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}

# %% [markdown]
# ## Comparison Operators

# %%
1 > 2

# %%
1 < 2

# %%
1 >= 1

# %%
1 <= 4

# %%
1 == 1

# %%
'hi' == 'bye'

# %% [markdown]
# ## Logic Operators

# %%
(1 > 2) and (2 < 3)

# %%
(1 > 2) or (2 < 3)

# %%
(1 == 2) or (2 == 3) or (4 == 4)

# %% [markdown]
# ## if,elif, else Statements

# %%
if 1 < 2:
    print('Yep!')

# %%
if 1 < 2:
    print('yep!')

# %%
if 1 < 2:
    print('first')
else:
    print('last')

# %%
if 1 > 2:
    print('first')
else:
    print('last')

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')

# %% [markdown]
# ## for Loops

# %% [markdown]
# A for loop is used for iterating over a sequence

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in seq:
    print('Yep')
# Out:
# Yep
# Yep
# Yep
# Yep
# Yep

# %%
for jelly in seq:
    print(jelly+jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## while Loops

# %% [markdown]
# With the while loop we can execute a set of statements as long as a condition is true.

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1
# Out:
# i is: 1
# i is: 2
# i is: 3
# i is: 4

# %% [markdown]
# ## range()

# %% [markdown]
# The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and stops before a specified number.

# %%
range(5)

# %%
for i in range(5):
    print(i)

# %%
list(range(5))

# %% [markdown]
# ## list comprehension

# %% [markdown]
# List comprehensions provide a concise way to create lists.

# %%
x = [1,2,3,4]

# %%
out = []
for item in x:
    out.append(item**2)
print(out)
# Out:
# [1, 4, 9, 16]

# %%
[item**2 for item in x]
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# ## functions

# %% [markdown]
# A function is a set of statements that take inputs, do some specific computation and produces output.

# %% [markdown]
# In Python a function is defined using the def keyword.

# %%
def my_func(param1='default'):
    """
    Docstring goes here.
    """
    print(param1)

# %%
my_func

# %%
my_func()

# %%
my_func('new param')

# %%
my_func(param1='new param')

# %%
def square(x):
    return x**2

# %%
out = square(2)
